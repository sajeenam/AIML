# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.info()
data.isnull().sum().sort_values().plot(kind = 'bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %% [markdown]
# * Majority of car column rows are NaN so dropping this is not a viable option and this field is not useful much.
# * Rest of the NaN field are neglectable so dropping thos.

# %%
data_nanc = data.dropna(axis = 0,subset = ['Bar', 'CarryAway',	'RestaurantLessThan20',	'Restaurant20To50'])
ans1 = data.shape[0] - data_nanc.shape[0]
print(ans1)
data_nanc.info()
# Out:
# 451
# <class 'pandas.core.frame.DataFrame'>
# Index: 12233 entries, 22 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12233 non-null  object
#  1   passanger             12233 non-null  object
#  2   weather               12233 non-null  object
#  3   temperature           12233 non-null  int64
#  4   time                  12233 non-null  object
#  5   coupon                12233 non-null  object
#  6   expiration            12233 non-null  object
#  7   gender                12233 non-null  object
#  8   age                   12233 non-null  object
#  9   maritalStatus         12233 non-null  object
#  10  has_children          12233 non-null  int64
#  11  education             12233 non-null  object
#  12  occupation            12233 non-null  object
#  13  income                12233 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# * 451 records containing NaN fields in Bar, CarryAway,RestaurantLessThan20 and Restaurant20To50 are dropped.
# Currently there are 12233 records available for data analysis.

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
total_accepted = (data_nanc['Y'].value_counts()[1]/data_nanc['Y'].value_counts().sum())*100
print (total_accepted)
# Out:
# 56.78901332461375

# %% [markdown]
# * A good percentage of the Drivers have accepted coupons.

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
fig1 = px.bar(data_nanc, x= "coupon", title="Count by Coupon",color="coupon",labels={"coupon":"Coupon"}, 
             color_discrete_sequence=["red", "green", "blue", "goldenrod", "magenta"],)
fig1.show()

# %% [markdown]
# * Most observations are on Coffee House and least observations are on expensive Restaurants.

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
fig2 = px.histogram(data_nanc,x="temperature",title="Histogram of temperature",labels={"temperature":"Temperature"},color_discrete_sequence = px.colors.qualitative.Dark24)
fig2.show()

# %% [markdown]
# * Most of these observations are taken on extreame weather conditions. It seems like it may be winter or Summer on these locations were the observations are taken.

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
data_bar = data_nanc.loc[data_nanc['coupon'] == 'Bar']
data_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1940 entries, 24 to 12682
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           1940 non-null   object
#  1   passanger             1940 non-null   object
#  2   weather               1940 non-null   object
#  3   temperature           1940 non-null   int64
#  4   time                  1940 non-null   object
#  5   coupon                1940 non-null   object
#  6   expiration            1940 non-null   object
#  7   gender                1940 non-null   object
#  8   age                   1940 non-null   object
#  9   maritalStatus         1940 non-null   object
#  10  has_children          1940 non-null   int64
#  11  education             1940 non-null   object
#  12  occupation            1940 non-null   object
#  13  income                1940 non-null   object
#  14  car                   13 non-null     object
# ...

# %% [markdown]
# * We have 1940 observation on Bar coupns

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
def acceptanceRate(y):
    return (y.value_counts()[1]/y.value_counts().sum())*100

total_accepted_bar_func = data_bar[['Y']].apply(acceptanceRate)
print(total_accepted_bar_func)
# Out:
# Y    40.927835
# dtype: float64

# %% [markdown]
# 40.92% of bar coupons are accepted among the 1940 of the avaialble observations. This is lower that the overall coupon acceptance percentage which is 56.78%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
bfc3 = ['less1','1~3']
bf3 = data_bar.query('Bar in @bfc3')

bfc4 = ['4~8','gt8']
bf4 = data_bar.query('Bar in @bfc4')

total_accepted_bar3 = bf3[['Y']].apply(acceptanceRate)
print (total_accepted_bar3)
total_accepted_bar4 = bf4[['Y']].apply(acceptanceRate)
print (total_accepted_bar4)
# Out:
# Y    52.386002
# dtype: float64
# Y    76.530612
# dtype: float64

# %% [markdown]
# * 52.38 % of drivers who went to a bar 3 or fewer times a month, have accepted the bar coupns. This is higher than the total bar coupons acceptance rate but lower than overall coupon acceptace rate which is 56.78%
# * 76.53% of drivers who went to bar more frequently accepted bar coupns. This is much higher than overall coupon acceptance rate.

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %% [markdown]
# * To prepare the calculations based on the age , age column needs to be updated to number. Before doing this data
# cleanup is done to remove additional characters in the age value.

# %%
bfc1m = ['1~3','4~8','gt8']
data_bar_age = data_bar.copy()
data_bar_age['age'].replace({'50plus' : 50, 'below21' : 20}, inplace=True)
data_bar_age['age'] = pd.to_numeric(data_bar_age['age'])

bf3age25 = data_bar_age.query('Bar in @bfc1m and age > 25')
total_accepted_bf3age25 = bf3age25[['Y']].apply(acceptanceRate)

notbf3age25 = data_bar_age.query('Bar not in @bfc1m and age <= 25')
total_accepted_notbf3age25 = notbf3age25[['Y']].apply(acceptanceRate)

print (total_accepted_bf3age25)
print (total_accepted_notbf3age25)
# Out:
# Y    69.211823
# dtype: float64
# Y    38.834951
# dtype: float64

# %% [markdown]
# * 69.21 % of drivers aged above 25 accepted bar coupns which is higher than the total bar coupons acceptance rate in general.
# * 38.83 % of drivers aged 25 or below accepted bar coupons , this shows young drivers are accepting less bar coupns than overall bar coupon acceptence by general pool of drivers.

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
psgr = ['Kid(s)','Alone']
ocptn = ['farming', 'fishing', 'forestry']

# it does not seems like occupation contains any of the three categories 'farming', 'fishing', 'forestry', we can check this as below
found = data_bar_age['occupation'].isin(ocptn).sum()
print(found)

psgr_ocptn_3 = data_bar_age.query('Bar in @bfc1m and passanger not in @psgr and occupation not in @ocptn')
total_accepted_psgr_ocptn_3 = psgr_ocptn_3[['Y']].apply(acceptanceRate)

not_psgr_3 = data_bar_age.query('Bar not in @bfc1m and passanger in @psgr')
total_accepted_not_psgr_3 = not_psgr_3[['Y']].apply(acceptanceRate)


print(total_accepted_psgr_ocptn_3)
print(total_accepted_not_psgr_3)
# Out:
# 0
# Y    71.727749
# dtype: float64
# Y    25.983437
# dtype: float64

# %% [markdown]
# * 71.72% of drivers, who does not have a kid passenger accepted bar coupns vs 25.98% acceptance with out kid passenger. This is much higher than the overall acceptance rate. So drivers are less likely to accept bar coupns when they are travelling with kids.
# * There is not enough data to compare drivers with or without ocupation in 'farming', 'fishing', 'forestry'.

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
rfc4m = ['4~8','gt8']
incml50k = ['$12500 - $24999', '$25000 - $37499','$37500 - $49999']
mrtlsts = ['widowed']
psgr_age_income = data_bar_age.query('Bar in @bfc1m and passanger not in @psgr and maritalStatus not in @mrtlsts | Bar in @bfc1m and age < 30 | RestaurantLessThan20 in @rfc4m and income in @incml50k')
psgr_age_income = psgr_age_income.drop_duplicates()
total_accepted_psgr_age_income = psgr_age_income[['Y']].apply(acceptanceRate)
print(total_accepted_psgr_age_income)

psgr_age_income_negate = data_bar_age.query('Bar not in @bfc1m and passanger in @psgr and maritalStatus in @mrtlsts | Bar not in @bfc1m and age >= 30 | RestaurantLessThan20 not in @rfc4m and income not in @incml50k')
psgr_age_income_negate = psgr_age_income_negate.drop_duplicates()
total_accepted_psgr_age_income_negate = psgr_age_income_negate[['Y']].apply(acceptanceRate)
print(total_accepted_psgr_age_income_negate)
# Out:
# Y    59.487179
# dtype: float64
# Y    33.822261
# dtype: float64

# %% [markdown]
# * Young drivers or drivers without kids passengers or drivers with low income background tends to accept much more bar coupns than general
# * Older drivers who are not bar goers or drivers with kids or drivers with higher income tend to accept less bar coupns than general.

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# * Bar coupons acceptance rate is lower that the overall coupon acceptance percentage.
# * Drivers who went to a bar 3 or fewer times a month, have accepted bar coupons than total bar coupons acceptance rate but lower than overall coupon acceptace rate which is 56.78%
# * Drivers who went to bar more frequently accepted bar coupns. This is much higher than overall coupon acceptance rate.
# * Drivers aged above 25 accepted bar coupns which is higher than the total bar coupons acceptance rate in general.
# * 61.34% of drivers, who does not have a kid passenger accepted bar coupns vs 28.74% acceptance with out kid passenger. This is much higher than the overall acceptance rate.
# * Young drivers or drivers without kids passengers or drivers with low income background tends to accept much more bar coupns than general

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# #### Investigating Coffee coupons

# %% [markdown]
# What propotion of the coffee coupons are accepted ?

# %%
coffee = data_nanc.loc[data_nanc['coupon'] == 'Coffee House']
coffee.info()
total_accepted_coffee = coffee[['Y']].apply(acceptanceRate)
print(total_accepted_coffee)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3860 entries, 23 to 12681
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           3860 non-null   object
#  1   passanger             3860 non-null   object
#  2   weather               3860 non-null   object
#  3   temperature           3860 non-null   int64
#  4   time                  3860 non-null   object
#  5   coupon                3860 non-null   object
#  6   expiration            3860 non-null   object
#  7   gender                3860 non-null   object
#  8   age                   3860 non-null   object
#  9   maritalStatus         3860 non-null   object
#  10  has_children          3860 non-null   int64
#  11  education             3860 non-null   object
#  12  occupation            3860 non-null   object
#  13  income                3860 non-null   object
#  14  car                   37 non-null     object
# ...

# %% [markdown]
# * 49.61 % is the acceptance rate of coffee coupons.

# %% [markdown]
# What is the acceptance rate of coffee coupons by weather

# %%
coffee.groupby('weather')[['Y']].value_counts().plot(kind = 'bar', ylabel='Count', xlabel = 'Weather', title='weather vs accept(1)/reject(0) count')



cfsnow = ['Snowy']
csnow = coffee.query('weather in @cfsnow')


notcsnow = coffee.query('weather not in @cfsnow')

total_accepted_csnow = csnow[['Y']].apply(acceptanceRate)
print (total_accepted_csnow)
total_accepted_notcsnow = notcsnow[['Y']].apply(acceptanceRate)
print (total_accepted_notcsnow)
# Out:
# Y    42.857143
# dtype: float64
# Y    50.168256
# dtype: float64

# %% [markdown]
# * It shows that slightly less number of people are accepted coupons when it is snowy weather compared to Rainy and Sunny weather conditions.
# * 42.83% is the acceptance rate when it is snowy
# * 50.16 % is the acceptance rate when it is not snowy

# %% [markdown]
# What is the acceptance rate for those you goes to coffee house more than once a month ?

# %%
cf1 = ['1~3','4~8','gt8']

cmorethan1 = coffee.query('CoffeeHouse in @cf1')


notcmorethan1 = coffee.query('CoffeeHouse not in @cf1')

total_accepted_cmorethan1 = cmorethan1[['Y']].apply(acceptanceRate)
print (total_accepted_cmorethan1)
total_accepted_notcmorethan1 = notcmorethan1[['Y']].apply(acceptanceRate)
print (total_accepted_notcmorethan1)
# Out:
# Y    65.899358
# dtype: float64
# Y    34.337349
# dtype: float64

# %% [markdown]
# 65.89% is the acceptance rate for those who visist coffee houses more than once a month.
# 34.33% is the acceptance rate for those who visit coffee house less than once in a month.
# Coffee coupon acceptance rate is high for those who visit coffee houses more than once a month compared to general acceptance rate.

# %% [markdown]
# What is the acceptance rate of coffee coupons during morning for those who visit coffee houses more than once a month?

# %%
cf1 = ['1~3','4~8','gt8']
mtime = ['7AM','10AM']

cmorethan1mrng = coffee.query('CoffeeHouse in @cf1 and time in @mtime')


notcmorethan1mrng = coffee.query('CoffeeHouse not in @cf1 and time not in @mtime')

total_accepted_cmorethan1mrng = cmorethan1mrng[['Y']].apply(acceptanceRate)
print (total_accepted_cmorethan1mrng)
total_accepted_notcmorethan1mrng = notcmorethan1mrng[['Y']].apply(acceptanceRate)
print (total_accepted_notcmorethan1mrng)
# Out:
# Y    69.722557
# dtype: float64
# Y    30.037313
# dtype: float64

# %% [markdown]
# * Coffee acceptance rate is higher in the morning for those who visit coffee houses more than once a month.
# * Drivers who visit coffee houses less than once a month are less likely to accept coupons in the evening than in the morning.

# %% [markdown]
# What is the acceptance rate of coupns for female customers in the morning among those who visit coffee houses more than once a month vs those who are not?

# %%
cmrngfml = coffee.query('CoffeeHouse in @cf1 and time in @mtime and gender == "Female" ')


notcmrngfml = coffee.query('CoffeeHouse not in @cf1 and time not in @mtime and gender == "Male" ')

total_accepted_cmrngfml = cmrngfml[['Y']].apply(acceptanceRate)
print (total_accepted_cmrngfml)
total_accepted_notcmrngfml = notcmrngfml[['Y']].apply(acceptanceRate)
print (total_accepted_notcmrngfml)
# Out:
# Y    71.588367
# dtype: float64
# Y    33.149171
# dtype: float64

# %% [markdown]
# * Female Drivers who visit coffee houses more than once a month tend to accept slightly more coffee coupons in the morning than in the afternoon.
# * Male drivers who visit coffee houses less than once a month tend accept coffee coupons than females in the afternoon.

# %% [markdown]
# time and destination

# %% [markdown]
# Compare the acceptance rates between those drivers who:
# go to coffee houses more than once a month, and are male OR
# go to coffee houses than once a month and are going on No Urgent place OR
# does not have Bachelors Degree/Graduate Degree and have Married partner

# %%
cocpn = ['Unemployed']
edcn = ['Bachelors degree', 'Graduate degree (Masters or Doctorate)', 'Some college - no degree']
ml_dge_nourgnt = coffee.query('CoffeeHouse in @cf1 and gender == "Male" and time in @mtime  | CoffeeHouse in @cf1 and destination =="No Urgent Place" | education not in @edcn and maritalStatus =="Married partner"')
ml_dge_nourgnt = ml_dge_nourgnt.drop_duplicates()
total_accepted_ml_dge_nourgnt = ml_dge_nourgnt[['Y']].apply(acceptanceRate)
print(total_accepted_ml_dge_nourgnt)

not_ml_dge_nourgnt = coffee.query('CoffeeHouse not in @cf1 and gender == "Female" and time not in @mtime  | CoffeeHouse not in @cf1 and destination !="No Urgent Place" | education in @edcn and maritalStatus !="Married partner"')
not_ml_dge_nourgnt = not_ml_dge_nourgnt.drop_duplicates()
total_accepted_not_ml_dge_nourgnt = not_ml_dge_nourgnt[['Y']].apply(acceptanceRate)
print(total_accepted_not_ml_dge_nourgnt)
# Out:
# Y    67.985348
# dtype: float64
# Y    44.032445
# dtype: float64

# %% [markdown]
# * Male drivers who visit coffee houses more than once a month OR on no urgent destination OR does not have a degree and have married partner tend to accept more coffee coupons than the negate of each of these three categories.

# %% [markdown]
# Hypothesis on drivers who accepted coffee coupons :

# %% [markdown]
# * 49.61 % is the acceptance rate of coffee coupons.
# * It shows that slightly less number of people are accepted coupons when it is snowy weather compared to Rainy and Sunny weather conditions.
# * 65.89% is the acceptance rate for those who visist coffee houses more than once a month.
# * Coffee coupon acceptance rate is high for those who visit coffee houses more than once a month compared to general acceptance rate.
# * Coffee acceptance rate is higher in the morning for those who visit coffee houses more than once a month.
# * Female Drivers who visit coffee houses more than once a month tend to accept slightly more coffee coupons in the morning than in the afternoon.
# * Male drivers who visit coffee houses less than once a month tend accept coffee coupons than females in the afternoon.
# * Male drivers who visit coffee houses more than once a month OR on no urgent destination OR does not have a degree and have married partner tend to accept more coffee coupons than the negate of each of these three categories.
